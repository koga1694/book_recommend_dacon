# %% [markdown]
# # load

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('train.csv')
test_original = pd.read_csv('test.csv')
sub = pd.read_csv('sample_submission.csv')

# %% [markdown]
# # EDA

# %%
data['User-ID'].value_counts()
# Out:
# USER_56601    11143
# USER_54845     6456
# USER_52453     5814
# USER_73501     4290
# USER_03411     3453
#               ...
# USER_39404        1
# USER_39405        1
# USER_39406        1
# USER_39408        1
# USER_92100        1
# Name: User-ID, Length: 83256, dtype: int64

# %%
data['Book-ID'].value_counts()
# Out:
# BOOK_097861    2502
# BOOK_050555     883
# BOOK_114855     768
# BOOK_206174     732
# BOOK_084346     723
#                ...
# BOOK_161877       1
# BOOK_139239       1
# BOOK_138283       1
# BOOK_133370       1
# BOOK_130798       1
# Name: Book-ID, Length: 243441, dtype: int64

# %%
data[data['User-ID'] == 'USER_00008']
# Out:
#               ID     User-ID      Book-ID  Book-Rating   Age  \
# 46  TRAIN_000046  USER_00008  BOOK_013473            7  37.0
# 47  TRAIN_000047  USER_00008  BOOK_031921            9  37.0
# 48  TRAIN_000048  USER_00008  BOOK_067104            0  37.0
# 49  TRAIN_000049  USER_00008  BOOK_104434            8  37.0
# 50  TRAIN_000050  USER_00008  BOOK_109072            8  37.0
# 51  TRAIN_000051  USER_00008  BOOK_130846            8  37.0
# 52  TRAIN_000052  USER_00008  BOOK_136516            8  37.0
# 53  TRAIN_000053  USER_00008  BOOK_140589            9  37.0
# 54  TRAIN_000054  USER_00008  BOOK_164536           10  37.0
# 55  TRAIN_000055  USER_00008  BOOK_172340            8  37.0
# 56  TRAIN_000056  USER_00008  BOOK_203922            0  37.0
# 57  TRAIN_000057  USER_00008  BOOK_208807            8  37.0
# 58  TRAIN_000058  USER_00008  BOOK_211579           10  37.0
# 59  TRAIN_000059  USER_00008  BOOK_218046            8  37.0
# 60  TRAIN_000060  USER_00008  BOOK_248248            8  37.0
#
#                 Location                                         Book-Title  \
# 46  vermilion, ohio, usa       Dr. Death (Alex Delaware Novels (Paperback))
# 47  vermilion, ohio, usa                                      Certain Smile
# 48  vermilion, ohio, usa                                  McNally's Dilemma
# 49  vermilion, ohio, usa                                      Double Impact
# 50  vermilion, ohio, usa                                       The Blessing
# 51  vermilion, ohio, usa                                     The Visitation
# 52  vermilion, ohio, usa                                        River's End
# 53  vermilion, ohio, usa                                   Kentucky Sunrise
# 54  vermilion, ohio, usa                                        Tell No One
# 55  vermilion, ohio, usa                                         2nd Chance
# 56  vermilion, ohio, usa                                         Stone Kiss
# 57  vermilion, ohio, usa                                     The Green Mile
# 58  vermilion, ohio, usa                          One Door Away from Heaven
# 59  vermilion, ohio, usa  Fast Food Nation: The Dark Side of the All-Ame...
# 60  vermilion, ohio, usa                       On the Street Where You Live
#
#            Book-Author  Year-Of-Publication                  Publisher
# 46  Jonathan Kellerman               2001.0           Ballantine Books
# 47      Judith Michael               1999.0           Random House Inc
# 48    Lawrence Sanders               1999.0        G. P. Putnam's Sons
# 49      Tess Gerritsen               2003.0                  Harlequin
# 50       Jude Deveraux               1998.0                      Atria
# 51       Frank Peretti               1999.0            Word Publishing
# 52        Nora Roberts               1999.0    Putnam Publishing Group
# 53       Fern Michaels               2003.0  Zebra Books (Mass Market)
# 54        Harlan Coben               2002.0    Dell Publishing Company
# 55     James Patterson               2003.0              Warner Vision
# 56      Faye Kellerman               2003.0               Warner Books
# 57        Stephen King               1999.0                     Pocket
# 58      Dean R. Koontz               2002.0               Bantam Books
# 59      Eric Schlosser               2002.0                  Perennial
# 60  Mary Higgins Clark               2002.0                     Pocket

# %%
test
# Out:
#                  ID     User-ID      Book-ID   Age  \
# 0       TEST_000000  USER_00008  BOOK_047966  37.0
# 1       TEST_000001  USER_00008  BOOK_119494  37.0
# 2       TEST_000002  USER_00008  BOOK_151775  37.0
# 3       TEST_000003  USER_00008  BOOK_176255  37.0
# 4       TEST_000004  USER_00008  BOOK_187307  37.0
# ...             ...         ...          ...   ...
# 159616  TEST_159616  USER_92086  BOOK_159050   0.0
# 159617  TEST_159617  USER_92086  BOOK_196481   0.0
# 159618  TEST_159618  USER_92086  BOOK_199754   0.0
# 159619  TEST_159619  USER_92086  BOOK_227481   0.0
# 159620  TEST_159620  USER_92086  BOOK_237054   0.0
#
#                               Location  \
# 0                 vermilion, ohio, usa
# 1                 vermilion, ohio, usa
# 2                 vermilion, ohio, usa
# 3                 vermilion, ohio, usa
# 4                 vermilion, ohio, usa
# ...                                ...
# 159616  mountain view, california, usa
# 159617  mountain view, california, usa
# 159618  mountain view, california, usa
# 159619  mountain view, california, usa
# 159620  mountain view, california, usa
#
#                                                Book-Title  \
# 0                      Birds of Prey: A Novel of Suspense
# 1                                         Midnight Voices
# 2       Breaking Free : A Prescription for Personal an...
# 3                                          Bitter Harvest
# 4                                   Embraced by the Light
# ...                                                   ...
# 159616                                 The Fat Flush Plan
# 159617  We Die Alone: A WWII Epic of Escape and Endurance
# 159618  From 60 Yards In : How to Master Golf's Short ...
# 159619                         Solo: On Her Own Adventure
# 159620        Avalanche Safety: For Skiers &amp; Climbers
#
#                  Book-Author  Year-Of-Publication  \
# 0                 J.A. Jance               2002.0
# 1                  JOHN SAUL               2003.0
# 2             David M.  Noer               1996.0
# 3                   Ann Rule               1999.0
# 4             Betty J. Eadie               1994.0
# ...                      ...                  ...
# 159616  Ann Louise Gittleman               2001.0
# 159617         David Howarth               1999.0
# 159618         Raymond Floyd               1992.0
# 159619      Susan Fox Rogers               1996.0
# 159620          Tony Daffern               1999.0
#
#                              Publisher
# 0                                 Avon
# 1                     Ballantine Books
# 2                          Jossey-Bass
# 3                               Pocket
# 4                         Bantam Books
# ...                                ...
# 159616  McGraw-Hill/Contemporary Books
# 159617                 The Lyons Press
# 159618                       Perennial
# 159619                 Seal Press (WA)
# 159620              Mountaineers Books
#
# [159621 rows x 9 columns]

# %%
test['User-ID'].unique().shape
# Out:
# (21909,)

# %%
data['User-ID'].unique().shape
# Out:
# (83256,)

# %%
check = data[data['User-ID'].isin(test['User-ID'].unique())]
check['User-ID'].unique().shape
# Out:
# (13064,)

# %% [markdown]
# train, test 내 같은 ID 존재함.
# 하지만 모든 아이디가 겹치는것은 아님
# train : 83256
# test : 21909
# train, test 중복 아이디 : 13064

# %%
data['location1'] = data['Location'].str.split(',').str[0]
data['location2'] = data['Location'].str.split(',').str[1]
data['location3'] = data['Location'].str.split(',').str[2]

# %%
import seaborn as sns
sns.pairplot(data[['Age', 'Year-Of-Publication']])

# %%
data['Age'].plot()
# Out:
# <Axes: >

# %%
data.describe()
# Out:
#          Book-Rating            Age  Year-Of-Publication
# count  871393.000000  871393.000000        871393.000000
# mean        2.820579      36.799861          1968.903339
# std         3.846906      12.065509           228.077752
# min         0.000000       0.000000            -1.000000
# 25%         0.000000      31.000000          1991.000000
# 50%         0.000000      35.000000          1997.000000
# 75%         7.000000      41.000000          2001.000000
# max        10.000000     244.000000          2021.000000

# %%
test.describe()
# Out:
#                  Age  Year-Of-Publication
# count  159621.000000        159621.000000
# mean       36.491289          1965.075566
# std        12.264977           244.301574
# min         0.000000            -1.000000
# 25%        30.000000          1992.000000
# 50%        35.000000          1997.000000
# 75%        40.000000          2001.000000
# max       237.000000          2021.000000

# %%
data[data['Age'] > 100].sort_values('Age')['Age'].value_counts()
# Out:
# 116.0    968
# 103.0    417
# 201.0    285
# 104.0    184
# 239.0    116
# 101.0    113
# 136.0     97
# 204.0     93
# 148.0     51
# 228.0     48
# 168.0     40
# 209.0     20
# 151.0     17
# 141.0     17
# 220.0     15
# 229.0     11
# 152.0     10
# 128.0      8
# 140.0      8
# 244.0      7
# 199.0      6
# 223.0      5
# 108.0      5
# 146.0      4
# 127.0      4
# 124.0      4
# 237.0      2
# 200.0      2
# 138.0      2
# 212.0      2
# 219.0      2
# 105.0      1
# 107.0      1
# 226.0      1
# 114.0      1
# 109.0      1
# 118.0      1
# 123.0      1
# 157.0      1
# 132.0      1
# 147.0      1
# Name: Age, dtype: int64

# %%
test[test['Age'] > 100] # 2022년 기준 미국 평균 수명 76.4세인데 ?
# Out:
#                  ID     User-ID      Book-ID    Age  \
# 327     TEST_000327  USER_00310  BOOK_003561  103.0
# 328     TEST_000328  USER_00310  BOOK_015234  103.0
# 329     TEST_000329  USER_00310  BOOK_020548  103.0
# 330     TEST_000330  USER_00310  BOOK_022821  103.0
# 331     TEST_000331  USER_00310  BOOK_023669  103.0
# ...             ...         ...          ...    ...
# 151072  TEST_151072  USER_86711  BOOK_234222  228.0
# 151073  TEST_151073  USER_86711  BOOK_252046  228.0
# 151374  TEST_151374  USER_87112  BOOK_121386  103.0
# 155721  TEST_155721  USER_89707  BOOK_258633  103.0
# 159548  TEST_159548  USER_91988  BOOK_174695  104.0
#
#                                     Location  \
# 327                    zanesville, ohio, usa
# 328                    zanesville, ohio, usa
# 329                    zanesville, ohio, usa
# 330                    zanesville, ohio, usa
# 331                    zanesville, ohio, usa
# ...                                      ...
# 151072              elverta, california, usa
# 151073              elverta, california, usa
# 151374  waalwijk, noord brabant, netherlands
# 155721             valencia, valencia, spain
# 159548         tinana, queensland, australia
#
#                                                Book-Title         Book-Author  \
# 327     One Mykonos: Being Ancient, Being Islands, Bei...      James Davidson
# 328     Tuesdays with Morrie: An Old Man, a Young Man,...         MITCH ALBOM
# 329     Man of the Century: The Life and Times of Pope...     Jonathan Kwitny
# 330     Krakatoa : The Day the World Exploded: August ...    Simon Winchester
# 331           Children of God (Ballantine Readers Circle)  Mary Doria Russell
# ...                                                   ...                 ...
# 151072                                 My Girl 2: A Novel     Patricia Hermes
# 151073         Introduction to Psychology (with InfoTrac)      James W. Kalat
# 151374  Cyber Rules : Strategies for Excelling at E-Bu...    Thomas M. Siebel
# 155721                 La Vida Sexual de Catherine Millet    Catherine Millet
# 159548                                     Killing Orders       Sara Paretsky
#
#         Year-Of-Publication                      Publisher
# 327                  2000.0             Thomas Dunne Books
# 328                  1997.0                      Doubleday
# 329                  1997.0       Henry Holt &amp; Company
# 330                  2003.0                  HarperCollins
# 331                  1999.0               Ballantine Books
# ...                     ...                            ...
# 151072               1994.0  Simon Spotlight Entertainment
# 151073               1999.0           Wadsworth Publishing
# 151374               1999.0                Doubleday Books
# 155721               2002.0                       Anagrama
# 159548               1993.0                           Dell
#
# [337 rows x 9 columns]

# %%
data[data['Age'] == 5]
# Out:
#                   ID     User-ID      Book-ID  Book-Rating  Age  \
# 15785   TRAIN_015785  USER_01811  BOOK_025537            6  5.0
# 15786   TRAIN_015786  USER_01811  BOOK_132948            0  5.0
# 54517   TRAIN_054517  USER_05563  BOOK_025790            5  5.0
# 54518   TRAIN_054518  USER_05563  BOOK_028426            0  5.0
# 54519   TRAIN_054519  USER_05563  BOOK_063873            5  5.0
# ...              ...         ...          ...          ...  ...
# 584012  TRAIN_584012  USER_60022  BOOK_118473            0  5.0
# 584013  TRAIN_584013  USER_60022  BOOK_215721            0  5.0
# 584014  TRAIN_584014  USER_60022  BOOK_240210            0  5.0
# 646065  TRAIN_646065  USER_67797  BOOK_015407            5  5.0
# 646066  TRAIN_646066  USER_67797  BOOK_076560            8  5.0
#
#                                    Location  \
# 15785               albany, california, usa
# 15786               albany, california, usa
# 54517                 lisboa, n/a, portugal
# 54518                 lisboa, n/a, portugal
# 54519                 lisboa, n/a, portugal
# ...                                     ...
# 584012    north reading, massachusetts, usa
# 584013    north reading, massachusetts, usa
# 584014    north reading, massachusetts, usa
# 646065  inver grove heights, minnesota, usa
# 646066  inver grove heights, minnesota, usa
#
#                                                Book-Title       Book-Author  \
# 15785   Barney &amp; B.J.: Go to the Fire Station (Bar...  Mark S. Bernthal
# 15786                Four Happy Teletubbies (Teletubbies)  Scholastic Books
# 54517                                 Lives of the Saints        Nino Ricci
# 54518                      Teach Yourself Basic Economics        F. Livesey
# 54519                                  In Desolate Heaven      Robert Edric
# ...                                                   ...               ...
# 584012                        George's Marvelous Medicine        Roald Dahl
# 584013                        Morgan and Me (Serendipity)  Stephen Cosgrove
# 584014  Little Mouse on the Prairie (Serendipity Books...  Stephan Cosgrove
# 646065                                        Rosies Walk      Pat Hutchins
# 646066  Chocolate Chippo Hippo (Beginning Literacy Sta...  Vincent Andriani
#
#         Year-Of-Publication                                    Publisher  \
# 15785                1996.0                            Barney Publishing
# 15786                1998.0                                   Scholastic
# 54517                1991.0                                      Minerva
# 54518                1987.0  Hodder &amp; Stoughton Educational Division
# 54519                  -1.0                        Firebird Distributing
# ...                     ...                                          ...
# 584012               1991.0                                 Puffin Books
# 584013               1978.0                            Price Stern Sloan
# 584014               1978.0                            Price Stern Sloan
# 646065                 -1.0                               Scholastic Inc
# 646066               1994.0                               Scholastic Inc
#
#                   location1       location2  location3
# 15785                albany      california        usa
# 15786                albany      california        usa
# 54517                lisboa             n/a   portugal
# 54518                lisboa             n/a   portugal
# 54519                lisboa             n/a   portugal
# ...                     ...             ...        ...
# 584012        north reading   massachusetts        usa
# 584013        north reading   massachusetts        usa
# 584014        north reading   massachusetts        usa
# 646065  inver grove heights       minnesota        usa
# 646066  inver grove heights       minnesota        usa
#
# [101 rows x 13 columns]

# %%
data['Year-Of-Publication'].value_counts()
# Out:
# 2002.0    77173
# 2001.0    67566
# 1999.0    64175
# 2000.0    61749
# 2003.0    60744
#           ...
# 2008.0        1
# 1909.0        1
# 1904.0        1
# 1378.0        1
# 1910.0        1
# Name: Year-Of-Publication, Length: 110, dtype: int64

# %%
test[test['Age'] == 5]
# Out:
#                  ID     User-ID      Book-ID  Age                   Location  \
# 44679   TEST_044679  USER_23089  BOOK_004622  5.0       omaha, nebraska, usa
# 44680   TEST_044680  USER_23089  BOOK_005269  5.0       omaha, nebraska, usa
# 44681   TEST_044681  USER_23089  BOOK_005769  5.0       omaha, nebraska, usa
# 44682   TEST_044682  USER_23089  BOOK_008587  5.0       omaha, nebraska, usa
# 44683   TEST_044683  USER_23089  BOOK_009582  5.0       omaha, nebraska, usa
# 44684   TEST_044684  USER_23089  BOOK_022049  5.0       omaha, nebraska, usa
# 44685   TEST_044685  USER_23089  BOOK_030824  5.0       omaha, nebraska, usa
# 44686   TEST_044686  USER_23089  BOOK_031381  5.0       omaha, nebraska, usa
# 44687   TEST_044687  USER_23089  BOOK_037759  5.0       omaha, nebraska, usa
# 44688   TEST_044688  USER_23089  BOOK_039237  5.0       omaha, nebraska, usa
# 44689   TEST_044689  USER_23089  BOOK_039816  5.0       omaha, nebraska, usa
# 44690   TEST_044690  USER_23089  BOOK_042226  5.0       omaha, nebraska, usa
# 44691   TEST_044691  USER_23089  BOOK_044514  5.0       omaha, nebraska, usa
# 44692   TEST_044692  USER_23089  BOOK_052684  5.0       omaha, nebraska, usa
# 44693   TEST_044693  USER_23089  BOOK_058093  5.0       omaha, nebraska, usa
# 44694   TEST_044694  USER_23089  BOOK_060265  5.0       omaha, nebraska, usa
# 44695   TEST_044695  USER_23089  BOOK_064017  5.0       omaha, nebraska, usa
# 44696   TEST_044696  USER_23089  BOOK_066647  5.0       omaha, nebraska, usa
# 44697   TEST_044697  USER_23089  BOOK_067220  5.0       omaha, nebraska, usa
# 44698   TEST_044698  USER_23089  BOOK_067683  5.0       omaha, nebraska, usa
# 44699   TEST_044699  USER_23089  BOOK_069895  5.0       omaha, nebraska, usa
# 44700   TEST_044700  USER_23089  BOOK_072365  5.0       omaha, nebraska, usa
# 44701   TEST_044701  USER_23089  BOOK_074261  5.0       omaha, nebraska, usa
# 44702   TEST_044702  USER_23089  BOOK_076962  5.0       omaha, nebraska, usa
# 44703   TEST_044703  USER_23089  BOOK_083671  5.0       omaha, nebraska, usa
# 44704   TEST_044704  USER_23089  BOOK_084197  5.0       omaha, nebraska, usa
# 44705   TEST_044705  USER_23089  BOOK_094807  5.0       omaha, nebraska, usa
# 44706   TEST_044706  USER_23089  BOOK_106903  5.0       omaha, nebraska, usa
# 44707   TEST_044707  USER_23089  BOOK_124602  5.0       omaha, nebraska, usa
# 44708   TEST_044708  USER_23089  BOOK_127151  5.0       omaha, nebraska, usa
# 44709   TEST_044709  USER_23089  BOOK_128731  5.0       omaha, nebraska, usa
# 44710   TEST_044710  USER_23089  BOOK_134110  5.0       omaha, nebraska, usa
# 44711   TEST_044711  USER_23089  BOOK_134521  5.0       omaha, nebraska, usa
# 44712   TEST_044712  USER_23089  BOOK_139638  5.0       omaha, nebraska, usa
# 44713   TEST_044713  USER_23089  BOOK_147750  5.0       omaha, nebraska, usa
# 44714   TEST_044714  USER_23089  BOOK_150012  5.0       omaha, nebraska, usa
# 44715   TEST_044715  USER_23089  BOOK_158737  5.0       omaha, nebraska, usa
# 44716   TEST_044716  USER_23089  BOOK_160034  5.0       omaha, nebraska, usa
# 44717   TEST_044717  USER_23089  BOOK_166637  5.0       omaha, nebraska, usa
# 44718   TEST_044718  USER_23089  BOOK_181065  5.0       omaha, nebraska, usa
# 44719   TEST_044719  USER_23089  BOOK_188746  5.0       omaha, nebraska, usa
# 44720   TEST_044720  USER_23089  BOOK_201826  5.0       omaha, nebraska, usa
# 44721   TEST_044721  USER_23089  BOOK_217520  5.0       omaha, nebraska, usa
# 44722   TEST_044722  USER_23089  BOOK_223290  5.0       omaha, nebraska, usa
# 44723   TEST_044723  USER_23089  BOOK_226106  5.0       omaha, nebraska, usa
# 44724   TEST_044724  USER_23089  BOOK_227191  5.0       omaha, nebraska, usa
# 44725   TEST_044725  USER_23089  BOOK_233000  5.0       omaha, nebraska, usa
# 44726   TEST_044726  USER_23089  BOOK_234573  5.0       omaha, nebraska, usa
# 44727   TEST_044727  USER_23089  BOOK_239508  5.0       omaha, nebraska, usa
# 44728   TEST_044728  USER_23089  BOOK_243831  5.0       omaha, nebraska, usa
# 44729   TEST_044729  USER_23089  BOOK_258698  5.0       omaha, nebraska, usa
# 44730   TEST_044730  USER_23089  BOOK_258930  5.0       omaha, nebraska, usa
# 44731   TEST_044731  USER_23089  BOOK_259368  5.0       omaha, nebraska, usa
# 44732   TEST_044732  USER_23089  BOOK_259847  5.0       omaha, nebraska, usa
# 44733   TEST_044733  USER_23089  BOOK_266287  5.0       omaha, nebraska, usa
# 44734   TEST_044734  USER_23089  BOOK_268045  5.0       omaha, nebraska, usa
# 133863  TEST_133863  USER_76657  BOOK_209785  5.0     alcoi, alicante, spain
# 139850  TEST_139850  USER_80827  BOOK_088066  5.0  temecula, california, usa
#
#                                                Book-Title  \
# 44679   The Magic School Bus Makes a Rainbow: A Book A...
# 44680                       Disney's Beauty and the Beast
# 44681     The Rugrats Movie Tommys New Playmate (Rugrats)
# 44682                           Jessie Bear What You Wear
# 44683   Earth: Where Would We Be Without It? (Golden L...
# 44684   Disney's: The Little Mermaid (Disney's Wonderf...
# 44685     Happy Easter, Little Critter (Look Look Series)
# 44686              Three Stories You Can Read to Your Dog
# 44687   The Poky Little Puppy's Counting Book (Golden ...
# 44688   The Berrylicious Bake-Off: A Scratch and Sniff...
# 44689                                God Made You Special
# 44690   The Magic School Bus: At the Waterworks (Magic...
# 44691   Marpel Is Stuck: And Other Really Good Reasons...
# 44692                         My G-r-r-r-reat Uncle Tiger
# 44693   Chills, Thrills, and Spills: Sid's Subzero Sur...
# 44694              Jumbo Animal Shaped Board Book: Kitten
# 44695   Ugly Duckling Sticker Storybook (Dover Little ...
# 44696                  Big Movers (Move &amp; Play Books)
# 44697              Goodnight Little Bear (ALLBOOK 60 5PT)
# 44698   The Magic School Bus Hops Home: A Book About A...
# 44699   The Magic School Bus Gets Programmed: A Book A...
# 44700                                          Underwater
# 44701   The Berenstain Bears and the Prize Pumpkin (Fi...
# 44702                                               Dumbo
# 44703                      Ice Age: Dinner with the Dodos
# 44704                                            Dragolin
# 44705              Little Red Riding Hood (First Stories)
# 44706               My First Barbie: Shapes at the Ballet
# 44707                        Goosey Goose (Thingy Things)
# 44708                   M Is for Monster (Monsters, Inc.)
# 44709   The Magic School Bus Blows Its Top: A Book Abo...
# 44710                     Snow White and the Seven Dwarfs
# 44711                             Pooh (Giant Board Book)
# 44712   The Mother Goose Book (Golden Book for Early C...
# 44713                                           Dog Brain
# 44714                             Chugga Chugga Choo Choo
# 44715                            Big Silver Space Shuttle
# 44716                                  All Things That Go
# 44717                 I Can Draw People (Playtime Series)
# 44718                        My Under the Sea Pop-Up Book
# 44719                 The Pagemaster (Golden Sound Story)
# 44720                 The Sesame Street 1, 2, 3 Storybook
# 44721                              Polar the Titanic Bear
# 44722              Three Stories You Can Read to Your Cat
# 44723   The Day the Sheep Showed Up (Hello Reader!, Le...
# 44724   Candy Land: The Colors of Candy Land (My First...
# 44725   The Magic School Bus Inside Ralphie: A Book Ab...
# 44726                                 My Favorite Seasons
# 44727                                           Dinosaurs
# 44728   The Magic School Bus Gets Ants in Its Pants: A...
# 44729   The Magic School Bus in the Haunted Museum: A ...
# 44730                    Ugly Duckling (Five Fairy Tales)
# 44731   The Magic School Bus Gets Eaten: A Book About ...
# 44732                              I Love You Stinky Face
# 44733                                    Our Solar System
# 44734   The Magic School Bus in the Arctic: A Book Abo...
# 133863                                         El mÃ©dico
# 139850         The Three Bears (First Little Golden Book)
#
#                         Book-Author  Year-Of-Publication  \
# 44679              Scholastic Books               1997.0
# 44680        First American Edition               1993.0
# 44681                    Luke David               1998.0
# 44682          Nancy White Carleson               1989.0
# 44683                    STEVE GRAY               1998.0
# 44684                   Walt Disney                 -1.0
# 44685                  MERCER MAYER               2000.0
# 44686              Sara Swan Miller               1997.0
# 44687                 Jean Chandler               1980.0
# 44688           Monique Z. Stephens               2003.0
# 44689                  Eric Metaxas               2002.0
# 44690                   Joanna Cole               1988.0
# 44691            Sandy Silverthorne               1999.0
# 44692                 James Riordan               2000.0
# 44693            Michael Teitelbaum               2002.0
# 44694                 Stephen Shott               2000.0
# 44695                   Marty Noble               1997.0
# 44696                   Matt Mitter               2001.0
# 44697                Leslie Mcguire               1996.0
# 44698                 Patricia Relf               1995.0
# 44699                   Nancy White               1999.0
# 44700                   Diana James               2000.0
# 44701               STAN BERENSTAIN               1990.0
# 44702                   Walt Disney               1996.0
# 44703                Leslie Goldman               2002.0
# 44704              Stephen Cosgrove               1995.0
# 44705                 Heather Amery               2003.0
# 44706                 Diane Muldrow               1998.0
# 44707                 Chris Raschka               2000.0
# 44708                 Mike Wazowski               2001.0
# 44709                   Joanna Cole               1996.0
# 44710                   Walt Disney                 -1.0
# 44711                   A. A. Milne               1999.0
# 44712                Nina Barbaresi               1982.0
# 44713                 David Milgrim               1996.0
# 44714                   Kevin Lewis               1999.0
# 44715                Ken Wilson-Max               1998.0
# 44716           Dandi Daley Mackall               1995.0
# 44717                    Ray Gibson               2000.0
# 44718                   Gill Davies               2002.0
# 44719                  Mary Dykstra               1994.0
# 44720                      Kinglsey               1973.0
# 44721   Daisy Corning Stone Spedden               2001.0
# 44722              Sara Swan Miller               1999.0
# 44723              David M. McPhail               1998.0
# 44724               Jackie Glassman               2002.0
# 44725                   Joanna Cole               1995.0
# 44726           Dandi Daley Mackall               1995.0
# 44727                  Gail Gibbons               1988.0
# 44728                   Joanna Cole               1996.0
# 44729                   Joanna Cole               1995.0
# 44730                Ladybird Books               1987.0
# 44731                 Patricia Relf               1996.0
# 44732                  Lisa McCourt               1997.0
# 44733                 Seymour Simon               1992.0
# 44734                   Joanna Cole               1998.0
# 133863                  Noah Gordon               2001.0
# 139850                  Carol North               2000.0
#
#                                    Publisher
# 44679                             Scholastic
# 44680              Grolier Book club Edition
# 44681            Simon Spotlight/Nickelodeon
# 44682             Scholastic Paperbacks (Mm)
# 44683                           Golden Books
# 44684                    Stoddart+publishing
# 44685                           Golden Books
# 44686                    Houghton Mifflin Co
# 44687                           Golden Books
# 44688                   Grosset &amp; Dunlap
# 44689                             Zonderkidz
# 44690                             Scholastic
# 44691                             Faith Kidz
# 44692                   Peachtree Publishers
# 44693                    HarperEntertainment
# 44694          Dorling Kindersley Publishing
# 44695                     Dover Publications
# 44696                        Reader's Digest
# 44697                        Reader's Digest
# 44698                             Scholastic
# 44699                             Scholastic
# 44700                     Two-Can Publishers
# 44701   Random House Books for Young Readers
# 44702                            Walt Disney
# 44703                     Perennial Currents
# 44704                  Price Stern Sloan Pub
# 44705                          Usborne Books
# 44706                           Golden Books
# 44707            Hyperion Books for Children
# 44708                              RH/Disney
# 44709                             Scholastic
# 44710                    Stoddart+publishing
# 44711                           Dutton Books
# 44712                           Golden Press
# 44713                           Viking Books
# 44714            Hyperion Books for Children
# 44715                        Cartwheel Books
# 44716                                Landoll
# 44717                          Usborne Books
# 44718                        Bumblebee Books
# 44719           Random House Childrens Books
# 44720          Random House Children's Books
# 44721                          Little, Brown
# 44722                    Houghton Mifflin Co
# 44723                        Cartwheel Books
# 44724                             Scholastic
# 44725                             Scholastic
# 44726                                Landoll
# 44727                          Holiday House
# 44728                             Scholastic
# 44729                             Scholastic
# 44730                         Ladybird Books
# 44731                             Scholastic
# 44732                   Troll Communications
# 44733                          HarperCollins
# 44734                       Magic School Bus
# 133863                        Suma de Letras
# 139850                          Golden Books

# %%
sub
# Out:
#                  ID  Book-Rating
# 0       TEST_000000            0
# 1       TEST_000001            0
# 2       TEST_000002            0
# 3       TEST_000003            0
# 4       TEST_000004            0
# ...             ...          ...
# 159616  TEST_159616            0
# 159617  TEST_159617            0
# 159618  TEST_159618            0
# 159619  TEST_159619            0
# 159620  TEST_159620            0
#
# [159621 rows x 2 columns]

# %%
! pip install fasttext
! pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pybind11>=2.2
#   Using cached pybind11-2.10.4-py3-none-any.whl (222 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from fasttext) (67.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from fasttext) (1.22.4)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp39-cp39-linux_x86_64.whl size=4395817 sha256=149e439008714f2b37b423edd8b13dec7d8cd0f5f92a3c95b1f807b11411df88
#   Stored in directory: /root/.cache/pip/wheels/64/57/bc/1741406019061d5664914b070bd3e71f6244648732bc96109e
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.2 pybind11-2.10.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (3.8.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nltk) (4.65.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk) (2022.10.31)

# %%
! pip install fasttext
! pip install nltk
! wget https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.en.300.bin.gz
! gunzip cc.en.300.bin.gz
import nltk
nltk.download('punkt')
# Out:
# --2023-04-17 04:26:15--  https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.en.300.bin.gz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 52.84.162.51, 52.84.162.20, 52.84.162.103, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|52.84.162.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4503593528 (4.2G) [application/octet-stream]
# Saving to: ‘cc.en.300.bin.gz’
#
# cc.en.300.bin.gz    100%[===================>]   4.19G   136MB/s    in 43s
#
# 2023-04-17 04:26:57 (101 MB/s) - ‘cc.en.300.bin.gz’ saved [4503593528/4503593528]

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import fasttext
import numpy as np
from nltk.tokenize import word_tokenize

# 사전 훈련된 FastText 모델 불러오기
fasttext_model = fasttext.load_model('cc.en.300.bin')

# 책 제목 예시
book_titles = [
    'The Catcher in the Rye',
    'To Kill a Mockingbird',
    'Pride and Prejudice',
    'The Great Gatsby'
]

# 책 제목 토큰화
tokenized_titles = [word_tokenize(title) for title in book_titles]

# 책 제목을 FastText 벡터로 변환
title_vectors = []
for title in tokenized_titles:
    title_vec = np.mean([fasttext_model.get_word_vector(word) for word in title], axis=0)
    title_vectors.append(title_vec)

title_vectors = np.array(title_vectors)

print(title_vectors)
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# [[-0.00815554  0.00059702  0.06773771 ...  0.14808312 -0.00483763
#    0.05659237]
#  [ 0.03220667 -0.16551088 -0.04816036 ...  0.23016986 -0.00796778
#   -0.03298334]
#  [ 0.04881931 -0.01057851 -0.00833939 ...  0.06204785 -0.00161936
#    0.04332691]
#  [ 0.01924547  0.04498987  0.08434889 ...  0.08690216 -0.04254525
#   -0.03398876]]

# %%
data['User-ID'].unique().shape
# Out:
# (83256,)

# %%
data[data['Age'] == 3].iloc[:20] # 3살까지 비정상 데이터. 4살부터는 좀 섞인듯함.
# Out:
#                  ID     User-ID      Book-ID  Book-Rating  Age  \
# 11488  TRAIN_011488  USER_01358  BOOK_001712            9  3.0
# 11489  TRAIN_011489  USER_01358  BOOK_007288            9  3.0
# 11490  TRAIN_011490  USER_01358  BOOK_019286            9  3.0
# 11491  TRAIN_011491  USER_01358  BOOK_021398            8  3.0
# 11492  TRAIN_011492  USER_01358  BOOK_023701            9  3.0
# 11493  TRAIN_011493  USER_01358  BOOK_029604            0  3.0
# 11494  TRAIN_011494  USER_01358  BOOK_035649            9  3.0
# 11495  TRAIN_011495  USER_01358  BOOK_042930            9  3.0
# 11496  TRAIN_011496  USER_01358  BOOK_050118            9  3.0
# 11497  TRAIN_011497  USER_01358  BOOK_052014            6  3.0
# 11498  TRAIN_011498  USER_01358  BOOK_055400            9  3.0
# 11499  TRAIN_011499  USER_01358  BOOK_059309            9  3.0
# 11500  TRAIN_011500  USER_01358  BOOK_072769            9  3.0
# 11501  TRAIN_011501  USER_01358  BOOK_103764            9  3.0
# 11502  TRAIN_011502  USER_01358  BOOK_117810            9  3.0
# 11503  TRAIN_011503  USER_01358  BOOK_127375            9  3.0
# 11504  TRAIN_011504  USER_01358  BOOK_145953            9  3.0
# 11505  TRAIN_011505  USER_01358  BOOK_158604            9  3.0
# 11506  TRAIN_011506  USER_01358  BOOK_178550            9  3.0
# 11507  TRAIN_011507  USER_01358  BOOK_185001            8  3.0
#
#                              Location  \
# 11488  charlotte, north carolina, usa
# 11489  charlotte, north carolina, usa
# 11490  charlotte, north carolina, usa
# 11491  charlotte, north carolina, usa
# 11492  charlotte, north carolina, usa
# 11493  charlotte, north carolina, usa
# 11494  charlotte, north carolina, usa
# 11495  charlotte, north carolina, usa
# 11496  charlotte, north carolina, usa
# 11497  charlotte, north carolina, usa
# 11498  charlotte, north carolina, usa
# 11499  charlotte, north carolina, usa
# 11500  charlotte, north carolina, usa
# 11501  charlotte, north carolina, usa
# 11502  charlotte, north carolina, usa
# 11503  charlotte, north carolina, usa
# 11504  charlotte, north carolina, usa
# 11505  charlotte, north carolina, usa
# 11506  charlotte, north carolina, usa
# 11507  charlotte, north carolina, usa
#
#                                               Book-Title        Book-Author  \
# 11488                                   Cellar of Horror        Ken Englade
# 11489  Partners in Evil: The Shocking True Story of a...      Steve Jackson
# 11490                                  Grave Accusations       Andrea Egger
# 11491  Bitter Medicine : Two Doctors, Two Deaths, And...      Carlton Smith
# 11492  Dead and Buried: A Shocking Account of Rape, T...     Corey Mitchell
# 11493  The No-Spin Zone: Confrontations with the Powe...      Bill O'Reilly
# 11494  Murder So Cold: A Father's Deadly Rage, a Daug...  Patricia Springer
# 11495                         Suffer the Little Children      Barbara Davis
# 11496   Out of Control (St. Martin's True Crime Library)        Steven Long
# 11497                                      Blood Highway     Sheila Johnson
# 11498                            Winter of Frozen Dreams        Karl Harter
# 11499                                           Triangle        Irene Pence
# 11500                                    Hometown Killer   Carol J. Rothgeb
# 11501  Love, Daddy : The True Story of Accused Con Ma...      Carlton Smith
# 11502                                    The Evil Mother         Fred Rosen
# 11503  Murder in Paradise (St. Martin's True Crime Li...      Lisa Pulitzer
# 11504                          The Coed Call Girl Murder   Fannie Weinstein
# 11505                                        Broken Doll         Burl Barer
# 11506                                  Married to Murder       Robert Scott
# 11507  Family Blood: The Murder That Shattered an All...         Lyn Riddle
#
#        Year-Of-Publication                         Publisher  location1  \
# 11488               1992.0           St. Martin's Paperbacks  charlotte
# 11489               2003.0                    Pinnacle Books  charlotte
# 11490               2004.0           St. Martin's True Crime  charlotte
# 11491               2000.0           St. Martin's True Crime  charlotte
# 11492               2003.0                    Pinnacle Books  charlotte
# 11493               2001.0                    Broadway Books  charlotte
# 11494               2004.0                    Pinnacle Books  charlotte
# 11495               1999.0                    Pinnacle Books  charlotte
# 11496               2004.0           St. Martin's Paperbacks  charlotte
# 11497               2004.0                    Pinnacle Books  charlotte
# 11498               1992.0                    Pinnacle Books  charlotte
# 11499               2001.0                    Pinnacle Books  charlotte
# 11500               2004.0                    Pinnacle Books  charlotte
# 11501               2003.0           St. Martin's True Crime  charlotte
# 11502               2004.0           St. Martin's Paperbacks  charlotte
# 11503               2003.0           St. Martin's True Crime  charlotte
# 11504               1997.0  St. Martin's True Crime Classics  charlotte
# 11505               2004.0                    Pinnacle Books  charlotte
# 11506               2004.0                    Pinnacle Books  charlotte
# 11507               2003.0                    Pinnacle Books  charlotte
#
#              location2 location3
# 11488   north carolina       usa
# 11489   north carolina       usa
# 11490   north carolina       usa
# 11491   north carolina       usa
# 11492   north carolina       usa
# 11493   north carolina       usa
# 11494   north carolina       usa
# 11495   north carolina       usa
# 11496   north carolina       usa
# 11497   north carolina       usa
# 11498   north carolina       usa
# 11499   north carolina       usa
# 11500   north carolina       usa
# 11501   north carolina       usa
# 11502   north carolina       usa
# 11503   north carolina       usa
# 11504   north carolina       usa
# 11505   north carolina       usa
# 11506   north carolina       usa
# 11507   north carolina       usa

# %% [markdown]
# # FE

# %%
! pip install fasttext
! pip install nltk
! wget https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.en.300.bin.gz
! gunzip cc.en.300.bin.gz
import nltk
nltk.download('punkt')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fasttext in /usr/local/lib/python3.9/dist-packages (0.9.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from fasttext) (1.22.4)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from fasttext) (67.6.1)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.9/dist-packages (from fasttext) (2.10.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (3.8.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nltk) (4.65.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk) (8.1.3)
# --2023-04-18 03:17:12--  https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.en.300.bin.gz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 13.249.141.13, 13.249.141.40, 13.249.141.108, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|13.249.141.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4503593528 (4.2G) [application/octet-stream]
# Saving to: ‘cc.en.300.bin.gz’
#
# cc.en.300.bin.gz    100%[===================>]   4.19G   177MB/s    in 35s
#
# 2023-04-18 03:17:47 (122 MB/s) - ‘cc.en.300.bin.gz’ saved [4503593528/4503593528]
#
# gzip: cc.en.300.bin already exists; do you wish to overwrite (y or n)? ㅜ
# 	not overwritten
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
! wget https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.en.300.bin.gz
! gunzip cc.en.300.bin.gz
# Out:
# 'wget'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# 'gunzip'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
data
# Out:
#                   ID     User-ID      Book-ID  Book-Rating   Age  \
# 0       TRAIN_000000  USER_00000  BOOK_044368            8  23.0
# 1       TRAIN_000001  USER_00000  BOOK_081205            8  23.0
# 2       TRAIN_000002  USER_00000  BOOK_086781            0  23.0
# 3       TRAIN_000003  USER_00000  BOOK_098622            0  23.0
# 4       TRAIN_000004  USER_00000  BOOK_180810            8  23.0
# ...              ...         ...          ...          ...   ...
# 871388  TRAIN_871388  USER_92096  BOOK_081138            0  34.0
# 871389  TRAIN_871389  USER_92097  BOOK_258124            0  35.0
# 871390  TRAIN_871390  USER_92098  BOOK_071848            0  45.0
# 871391  TRAIN_871391  USER_92099  BOOK_252599            8  43.0
# 871392  TRAIN_871392  USER_92100  BOOK_130798            0  35.0
#
#                                      Location  \
# 0            sackville, new brunswick, canada
# 1            sackville, new brunswick, canada
# 2            sackville, new brunswick, canada
# 3            sackville, new brunswick, canada
# 4            sackville, new brunswick, canada
# ...                                       ...
# 871388            minneapolis, minnesota, usa
# 871389                     temple, texas, usa
# 871390                ottawa, ontario, canada
# 871391            maple grove, minnesota, usa
# 871392  castiglion fiorentino, toscana, italy
#
#                                                Book-Title  \
# 0                                              Road Taken
# 1                       Macbeth (New Penguin Shakespeare)
# 2                      Waverley (Penguin English Library)
# 3                                 Mother Earth Father Sky
# 4                                       She Who Remembers
# ...                                                   ...
# 871388  Healing Words: The Power of Prayer and the Pra...
# 871389  The Salmon of Doubt: Hitchhiking the Galaxy On...
# 871390  Harry Potter and the Prisoner of Azkaban (Book 3)
# 871391            Heartbreak Hill: Anatomy of a Ryder Cup
# 871392  The Coffin Quilt: The Feud between the Hatfiel...
#
#                 Book-Author  Year-Of-Publication                  Publisher  \
# 0                Rona Jaffe               2001.0                       Mira
# 1       William Shakespeare               1981.0              Penguin Books
# 2              Walter Scott               1981.0              Penguin Books
# 3              Sue Harrison               1991.0                       Avon
# 4          Linda Lay Shuler               1989.0                Signet Book
# ...                     ...                  ...                        ...
# 871388         Larry Dossey               1993.0              Harpercollins
# 871389        DOUGLAS ADAMS               2002.0                    Harmony
# 871390        J. K. Rowling               2000.0            Thorndike Press
# 871391        Tim Rosaforte               1996.0              St Martins Pr
# 871392          Ann Rinaldi               1999.0  Harcourt Children's Books
#
#                     location1      location2 location3
# 0                   sackville  new brunswick    canada
# 1                   sackville  new brunswick    canada
# 2                   sackville  new brunswick    canada
# 3                   sackville  new brunswick    canada
# 4                   sackville  new brunswick    canada
# ...                       ...            ...       ...
# 871388            minneapolis      minnesota       usa
# 871389                 temple          texas       usa
# 871390                 ottawa        ontario    canada
# 871391            maple grove      minnesota       usa
# 871392  castiglion fiorentino        toscana     italy
#
# [871393 rows x 13 columns]

# %%
# import fasttext
import numpy as np
# from nltk.tokenize import word_tokenize
from sklearn.preprocessing import LabelEncoder
import re
# 사전 훈련된 FastText 모델 불러오기
# fasttext_model = fasttext.load_model('cc.en.300.bin')
def FE(x):

  '''
  네, 다른 분류 체계 중 하나로는 Erik Erikson이 제안한 발달 심리학의 8단계 이론이 있습니다. 이 이론은 사람의 삶 전체를 8개의 단계로 구분하고 각 단계에서 나타나는 발달 과제와 이를 이루는데 필요한 심리적 발달을 설명합니다. 각 단계와 그 발달 과제는 아래와 같습니다.

  신생아기 (0-1세) - 신뢰 대 불신
  유아기 (1-3세) - 자율성 대 의지력
  유아기 후기 (3-6세) - 산업성 대 열등감
  학령기 (6-12세) - 적극성 대 열등감
  십대 초기 (12-18세) - 정체성 형성 대 혼돈
  젊은 성인기 (18-40세) - 친밀성 대 고립
  중년기 (40-65세) - 생산성 대 스타그네이션
  노년기 (65세 이상) - 자기완성 대 절망

  유치원 (Kindergarten): 5-6세 (일부 지역에서는 4세부터 가능)

  초등학교 (Elementary school): 6-11세 (1학년부터 6학년까지)

  중학교 (Middle school): 11-14세 (6학년/7학년부터 8학년까지)

  고등학교 (High school): 14-18세 (9학년부터 12학년까지)

  대학교 (College/University): 18세 이상 (일부 대학교에서는 17세도 입학 가능하며, 대학교 졸업 나이는 다양합니다.)

  초기 성인기 (18-25세): 대학교에 입학하여 직업과 삶의 방향성을 탐색하며, 자립적인 삶의 기초를 다지는 시기입니다.

  중반 성인기 (26-30세): 자신의 생활과 경력에 대한 방향성과 목표를 더욱 구체적으로 정립하고, 사회적 책임감이나 가족 등 새로운 책임들을 맡기 시작하는 시기입니다.

  후반 성인기 (31-40세): 이전의 삶에서 중요하게 생각했던 것들을 재평가하며, 현재의 삶의 방향성을 새롭게 재설정하는 시기입니다. 이 시기에는 가족 형성, 직업적인 안정성, 사회적 존경 등을 중요하게 생각하게 됩니다.
  
  초기 중년기 (40-50세): 직장에서의 경력과 성취를 더욱 중요시하며, 건강과 가족, 개인의 행복 등에 대한 책임을 더욱 느끼는 시기입니다.

  중반 중년기 (51-60세): 가족과 사회적인 지위를 중시하며, 가족과 친구들과 함께 시간을 보내는 것을 중요하게 생각합니다. 이 시기에는 많은 사람들이 자신의 인생을 다시 평가하고, 새로운 삶의 방향성을 모색하게 됩니다.

  후반 중년기 (61-65세): 자신의 남은 인생에 대한 계획과 목표를 더욱 구체적으로 설정하며, 건강과 재정적인 안정을 더욱 중요시하는 시기입니다. 이 시기에는 일부 사람들이 은퇴하며, 새로운 취미나 관심사를 찾는 등 새로운 경험을 쌓으며 삶을 즐기는 것을 추구하기도 합니다.
  
  일반 노인 (65-74세): 퇴직 후 휴식과 여가 생활을 즐기며, 가족과 친구들과 함께 시간을 보내는 것을 중요하게 생각합니다. 이 시기에는 건강에 대한 관심이 높아지며, 건강한 삶을 유지하기 위해 규칙적인 운동, 건강한 식습관 등을 유지하는 것이 중요합니다.

  안부 노인 (75-84세): 건강상의 문제로 인해 실제로 활동할 수 있는 시간이 줄어들며, 가족과 친구들과 함께 시간을 보내는 것을 더욱 중요시합니다. 이 시기에는 신체적인 기능이 떨어지기 때문에 건강 관리가 매우 중요합니다.

  고령 노인 (85세 이상): 건강상의 문제로 인해 일상 생활에 도움이 필요하게 되며, 대부분의 시간을 가족이나 간병인과 함께 보내게 됩니다. 이 시기에는 건강한 삶을 유지하기 위한 노력이 중요하지만, 이전 단계와 달리 적극적인 건강 관리가 어려울 수 있습니
  '''
  # 지역 split
  x['location1'] = x['Location'].str.split(',').str[0]
  x['location2'] = x['Location'].str.split(',').str[1]
  x['location3'] = x['Location'].str.split(',').str[2]

  x['location1'] = x['location1'].astype(str)
  x['location2'] = x['location2'].astype(str)
  x['location3'] = x['location3'].astype(str)

  
  x = x.replace({'no' : 'n/a'})

  # 정규표현식 패턴 설정
  pattern = r'[^a-zA-Z\s]'  # 알파벳과 공백을 제외한 모든 문자

  # 특정 컬럼의 모든 문자열에 대해 패턴에 맞지 않는 문자 제거
  x['location1'] = x['location1'].apply(lambda x: re.sub(pattern, '', x))
  x['location2'] = x['location2'].apply(lambda x: re.sub(pattern, '', x))
  x['location3'] = x['location3'].apply(lambda x: re.sub(pattern, '', x))
  
  x['location1'] = x['location1'].apply(lambda x:x.strip())
  x['location2'] = x['location2'].apply(lambda x:x.strip())
  x['location3'] = x['location3'].apply(lambda x:x.strip())
  
  x['location1'] = x['location1'].replace('\s+', ' ', regex=True)
  x['location2'] = x['location2'].replace('\s+', ' ', regex=True)
  x['location3'] = x['location3'].replace('\s+', ' ', regex=True)

  # 저자, 출판사 특수문자, 공백 제거
  x['Book-Author'] = x['Book-Author'].astype(str)
  x['Publisher'] = x['Publisher'].astype(str)
  x['Book-Author'] = x['Book-Author'].apply(lambda x: re.sub(pattern, '', x))
  x['Publisher'] = x['Publisher'].apply(lambda x: re.sub(pattern, '', x))
  x['Book-Author'] = x['Book-Author'].replace('\s+', ' ', regex=True)
  x['Publisher'] = x['Publisher'].replace('\s+', ' ', regex=True)
  x['Book-Author'] = x['Book-Author'].str.replace(' ', '')
  x['Publisher'] = x['Publisher'].str.replace(' ', '')

  # 책 타이틀도 공백제거, 문자열만 남기기.
  x['Book-Title'] = x['Book-Title'].astype(str)
  x['Book-Title'] = x['Book-Title'].apply(lambda x: re.sub(pattern, '', x))
  x['Book-Title'] = x['Book-Title'].replace('\s+', ' ', regex=True)
  x['Book-Title'] = x['Book-Title'].apply(lambda x:x.strip())
  

  x['Age_fe'] = np.NaN
  x.loc[x['Age'] < 4, 'Age_fe'] = 0 # 정상데이터가 있는지도 몰루
  x.loc[((4 <= x['Age']) & (x['Age'] < 6)), 'Age_fe'] = 1
  x.loc[((6 <= x['Age']) & (x['Age'] < 12)), 'Age_fe'] = 2
  x.loc[((12 <= x['Age']) & (x['Age'] < 15)), 'Age_fe'] = 3
  x.loc[((15 <= x['Age']) & (x['Age'] < 18)), 'Age_fe'] = 4
  x.loc[((18 <= x['Age']) & (x['Age'] < 25)), 'Age_fe']= 5
  x.loc[((26 <= x['Age']) & (x['Age'] < 30)), 'Age_fe'] = 6
  x.loc[((30 <= x['Age']) & (x['Age'] < 40)), 'Age_fe'] = 7
  x.loc[((40 <= x['Age']) & (x['Age'] < 50)), 'Age_fe'] = 8
  x.loc[((50 <= x['Age']) & (x['Age'] < 60)), 'Age_fe'] = 9
  x.loc[((60 <= x['Age']) & (x['Age'] < 65)), 'Age_fe'] = 10
  x.loc[((65 <= x['Age']) & (x['Age'] < 75)), 'Age_fe'] = 11
  x.loc[((75 <= x['Age']) & (x['Age'] < 85)), 'Age_fe'] = 12
  x.loc[85 <= x['Age'], 'Age_fe'] = 13
  # title_vectors = []

  # def apy(df):
  #   # 책 제목 토큰화
  #   tokenized_titles = [word_tokenize(title) for title in df]

  # # 책 제목을 FastText 벡터로 변환
  #   for title in tokenized_titles:
  #       title_vec = np.mean([fasttext_model.get_word_vector(word) for word in title], axis=0)
  #       title_vectors.append(title_vec)
  

  return x 
  
train = FE(data)
test = FE(test_original)

# %% [markdown]
# ## 나라 전처리

# %%
train['location3'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 train['location3'].unique()
#
# NameError: name 'train' is not defined

# %% [markdown]
# ### state, country 채우기

# %%
# 주 채우기
dum  = train.groupby('location1')['location2'].value_counts().to_frame().rename(columns = {'location2' : 'count'}).reset_index()
dum = dum[dum['location1'] !='']
dum = dum[dum['location2'] !='']
dum = dum[dum['location2'] != 'na']
dum = dum[dum['location2'] != 'nan']
dum = dum[dum['location1'] != 'na']
dum = dum[dum['location1'] != 'nan']
dum = dum[dum['count'] != 1]
# dum = dum[~(dum['location1'] == dum['location2'])] # 도시이름이 주에 들어간 경우가 있음.

# 중복값 제거 및 조건부 선택
dum= dum.sort_values(by=['location1', 'count'], ascending=[True, False]).drop_duplicates(subset='location1', keep='first')

cat_train1 = train[(train['location1'].isin(dum['location1'].unique()))]
cat_train2 = train[~(train['location1'].isin(dum['location1'].unique()))]

# 테스트셋은 모른다고 가정하여 학습데이터셋 기준으로 전처리한다.
cat_test1 = test[(test['location1'].isin(dum['location1'].unique()))]
cat_test2 = test[~(test['location1'].isin(dum['location1'].unique()))]

cat_train1 = pd.merge(cat_train1.drop('location2', axis=1), dum[['location1', 'location2']], how='left', on='location1')
cat_test1 = pd.merge(cat_test1.drop('location2', axis=1), dum[['location1', 'location2']], how='left', on='location1')
ct1 = pd.concat([cat_train1, cat_train2])
ct2 = pd.concat([cat_test1, cat_test2])

# %%
# 나라 채우기
dum = ct1.groupby('location2')['location3'].value_counts().to_frame().rename(columns = {'location3' : 'count'}).reset_index()
dum = dum[dum['location2'] !='']
dum = dum[dum['location3'] !='']
dum = dum[dum['location2'] != 'na']
dum = dum[dum['location2'] != 'nan']
dum = dum[dum['location2'] != 'na']
dum = dum[dum['location3'] != 'nan']
dum = dum[dum['count'] != 1]
# dum = dum[~(dum['location2'] == dum['location3'])] # 도시이름이 주에 들어간 경우가 있음.

# 중복값 제거 및 조건부 선택
dum= dum.sort_values(by=['location2', 'count'], ascending=[True, False]).drop_duplicates(subset='location2', keep='first')

cat_ct1 = ct1[(ct1['location2'].isin(dum['location2'].unique()))]
cat_ct2 = ct1[~(ct1['location2'].isin(dum['location2'].unique()))]

# 테스트셋은 모른다고 가정하여 학습데이터셋 기준으로 전처리한다.
cat_ctt1 = ct2[(ct2['location2'].isin(dum['location2'].unique()))]
cat_ctt2 = ct2[~(ct2['location2'].isin(dum['location2'].unique()))]

cat_ct1 = pd.merge(cat_ct1.drop('location3', axis=1), dum[['location2', 'location3']], how='left', on='location2')
cat_ctt1 = pd.merge(cat_ctt1.drop('location3', axis=1), dum[['location2', 'location3']], how='left', on='location2')
trainset = pd.concat([cat_ct1, cat_ct2])
testset = pd.concat([cat_ctt1, cat_ctt2])

# %%
trainset = trainset.replace({'nan' : 'na', '' : 'na'})
testset = testset.replace({'nan' : 'na', '' : 'na'})

trainset.loc[trainset['Book-Title'] == ' ', 'Book-Title'] = 'na'
testset.loc[testset['Book-Title'] == ' ', 'Book-Title'] = 'na'

# trainset.loc[trainset['Book-Title'] == '  ', 'Book-Title'] = 'na'
# testset.loc[testset['Book-Title'] == '  ', 'Book-Title'] = 'na'

# %%
# 책 -1 채우기 - 폐기
# dum = trainset[trainset['Book-Title'] != 'na']['Book-Title'].unique()
# dum = trainset[trainset['Book-Title'].isin(dum)]
# dum = dum.groupby(['Book-Title', 'Book-Author', 'Publisher'])['Year-Of-Publication'].max().to_frame()
# # dum = dum[dum['Year-Of-Publication'] != -1].index.to_list()
# dum = dum[dum['Year-Of-Publication'] != -1].reset_index()
# # dum
# dum = dum.groupby(['Book-Title', 'Book-Author', 'Publisher'])['Year-Of-Publication'].value_counts().to_frame().rename(
#     columns = {'Year-Of-Publication' : 'count'}).reset_index()
# dum = dum.sort_values(by=['Book-Title', 'Book-Author', 'Publisher', 'count'], 
#                       ascending=[True,True,True, False]).drop_duplicates(subset=['Book-Title', 'Book-Author', 'Publisher'], keep='first')
 
# cat_trainset1 = trainset[(trainset['Book-Title'].isin(dum['Book-Title'].unique()))]
# cat_trainset2 = trainset[~(trainset['Book-Title'].isin(dum['Book-Title'].unique()))]

# # 테스트셋은 모른다고 가정하여 학습데이터셋 기준으로 전처리한다.
# cat_testset1 = testset[(testset['Book-Title'].isin(dum['Book-Title'].unique()))]
# cat_testset2 = testset[~(testset['Book-Title'].isin(dum['Book-Title'].unique()))]

# cat_trainset1 = pd.merge(cat_trainset1.drop('Year-Of-Publication', axis=1), dum[['Book-Title', 'Year-Of-Publication']], how='left', on='Book-Title')
# cat_testset1 = pd.merge(cat_testset1.drop('Year-Of-Publication', axis=1), dum[['Book-Title', 'Year-Of-Publication']], how='left', on='Book-Title')
# trainset = pd.concat([cat_trainset1, cat_trainset2])
# testset = pd.concat([cat_testset1, cat_testset2])

# %%
# -1 제외한 연도를 MINMAXSCALER 적용해서 넣자.
from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler()
mm.fit(trainset.loc[~trainset['Year-Of-Publication'].isin([-1]), 'Year-Of-Publication'].to_numpy().reshape(-1, 1))
trainset.loc[~trainset['Year-Of-Publication'].isin([-1]), 'Year-Of-Publication'] = mm.transform(trainset.loc[~trainset['Year-Of-Publication'].isin([-1]), 'Year-Of-Publication'].to_numpy().reshape(-1, 1))
testset.loc[~testset['Year-Of-Publication'].isin([-1]), 'Year-Of-Publication'] = mm.transform(testset.loc[~testset['Year-Of-Publication'].isin([-1]), 'Year-Of-Publication'].to_numpy().reshape(-1, 1))

# %% [markdown]
# # 텍스트 벡터

# %%
book_title= pd.concat([trainset['Book-Title'], testset['Book-Title']]).drop_duplicates().to_frame().reset_index().drop('index', axis=1)

# %%
import fasttext.util
import fasttext
fasttext.util.download_model('en', if_exists='ignore')  # English
model = fasttext.load_model('cc.en.300.bin')



vectors = []
for title in book_title['Book-Title']:
    vector = model.get_sentence_vector(title)
    vectors.append(vector)

vectors = pd.DataFrame(vectors)

book_title = pd.concat([book_title, vectors], axis=1)
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
# dum = book_title.iloc[:, 1:]

# book_title[book_title[0] == 0] # 벡터가 0인 경우 존재.

# book_title_vectors = book_title.drop(book_title[book_title[0] == 0].index)

# %%
'''
메모리 에러로 불가함. 배치로 나눠서 하는 방법 있으나 과연 그게 효과가 있을지 잘 모르겠음..
그리고 테스트셋도 사용하기 때문에 leak에 해당하는거 같음. 안하는게 좋을듯?
'''

# from sklearn.cluster import AgglomerativeClustering
# from sklearn.metrics import silhouette_score
# from sklearn.preprocessing import normalize


# book_title_vectors = book_title_vectors.iloc[:, 1:].values

# # 벡터 정규화
# book_title_vectors = normalize(book_title_vectors)

# # AgglomerativeClustering을 이용하여 클러스터링 수행
# s_scores = []
# for n_clusters in range(2, 20):
#     cluster_model = AgglomerativeClustering(n_clusters=n_clusters, affinity='cosine', linkage='average')
#     cluster_labels = cluster_model.fit_predict(book_title_vectors)

#     s_score = silhouette_score(book_title_vectors, cluster_labels, metric='cosine')
#     s_scores.append(s_score)

#     print(f"Clusters: {n_clusters}  Silhouette Score: {s_score:.3f}")

# # 적절한 클러스터링 개수 선택
# best_n_clusters = np.argmax(s_scores) + 2
# print(f"Best number of clusters: {best_n_clusters}")
# Out:
# C:\Users\signlab026\AppData\Roaming\Python\Python38\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[35], line 15
#      13 for n_clusters in range(2, 20):
#      14     cluster_model = AgglomerativeClustering(n_clusters=n_clusters, affinity='cosine', linkage='average')
# ---> 15     cluster_labels = cluster_model.fit_predict(book_title_vectors)
#      17     s_score = silhouette_score(book_title_vectors, cluster_labels, metric='cosine')
#      18     s_scores.append(s_score)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\cluster\_agglomerative.py:1099, in AgglomerativeClustering.fit_predict(self, X, y)
#    1078 def fit_predict(self, X, y=None):
#    1079     """Fit and return the result of each sample's clustering assignment.
#    1080
#    1081     In addition to fitting, this method also return the result of the
#    (...)
#    1097         Cluster labels.
#    1098     """
# -> 1099     return super().fit_predict(X, y)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\base.py:723, in ClusterMixin.fit_predict(self, X, y)
#     705 """
#     706 Perform clustering on `X` and returns cluster labels.
#     707
#    (...)
#     719     Cluster labels.
#     720 """
#     721 # non-optimized default implementation; override when a better
#     722 # method is possible for a given clustering algorithm
# --> 723 self.fit(X)
#     724 return self.labels_
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\cluster\_agglomerative.py:956, in AgglomerativeClustering.fit(self, X, y)
#     954 self._validate_params()
#     955 X = self._validate_data(X, ensure_min_samples=2)
# --> 956 return self._fit(X)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\cluster\_agglomerative.py:1046, in AgglomerativeClustering._fit(self, X)
#    1042 distance_threshold = self.distance_threshold
#    1044 return_distance = (distance_threshold is not None) or self.compute_distances
# -> 1046 out = memory.cache(tree_builder)(
#    1047     X,
#    1048     connectivity=connectivity,
#    1049     n_clusters=n_clusters,
#    1050     return_distance=return_distance,
#    1051     **kwargs,
#    1052 )
#    1053 (self.children_, self.n_connected_components_, self.n_leaves_, parents) = out[
#    1054     :4
#    1055 ]
#    1057 if return_distance:
#
# File c:\Users\signlab026\.pyenv\pyenv-win\versions\3.8.10\lib\site-packages\joblib\memory.py:349, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     348 def __call__(self, *args, **kwargs):
# --> 349     return self.func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\cluster\_agglomerative.py:670, in _average_linkage(*args, **kwargs)
#     668 def _average_linkage(*args, **kwargs):
#     669     kwargs["linkage"] = "average"
# --> 670     return linkage_tree(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\sklearn\cluster\_agglomerative.py:544, in linkage_tree(X, connectivity, n_clusters, linkage, affinity, return_distance)
#     542     out = _hierarchical.single_linkage_label(mst)
#     543 else:
# --> 544     out = hierarchy.linkage(X, method=linkage, metric=affinity)
#     545 children_ = out[:, :2].astype(int, copy=False)
#     547 if return_distance:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\scipy\cluster\hierarchy.py:1060, in linkage(y, method, metric, optimal_ordering)
#    1056         if np.all(y >= 0) and np.allclose(y, y.T):
#    1057             _warning('The symmetric non-negative hollow observation '
#    1058                      'matrix looks suspiciously like an uncondensed '
#    1059                      'distance matrix')
# -> 1060     y = distance.pdist(y, metric)
#    1061 else:
#    1062     raise ValueError("`y` must be 1 or 2 dimensional.")
#
# File ~\AppData\Roaming\Python\Python38\site-packages\scipy\spatial\distance.py:2250, in pdist(X, metric, out, **kwargs)
#    2248 if metric_info is not None:
#    2249     pdist_fn = metric_info.pdist_func
# -> 2250     return pdist_fn(X, out=out, **kwargs)
#    2251 elif mstr.startswith("test_"):
#    2252     metric_info = _TEST_METRICS.get(mstr, None)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\scipy\spatial\distance.py:1720, in PDistMetricWrapper.__call__(self, X, out, **kwargs)
#    1716     metric = metric_info.dist_func
#    1717     return _pdist_callable(
#    1718         X, metric=metric, out=out, w=w, **kwargs)
# -> 1720 dm = _prepare_out_argument(out, np.double, (out_size,))
#    1721 # get pdist wrapper
#    1722 pdist_fn = getattr(_distance_wrap, f'pdist_{metric_name}_{typ}_wrap')
#
# File ~\AppData\Roaming\Python\Python38\site-packages\scipy\spatial\distance.py:2583, in _prepare_out_argument(out, dtype, expected_shape)
#    2581 def _prepare_out_argument(out, dtype, expected_shape):
#    2582     if out is None:
# -> 2583         return np.empty(expected_shape, dtype=dtype)
#    2585     if out.shape != expected_shape:
#    2586         raise ValueError("Output array has incorrect shape.")
#
# MemoryError: Unable to allocate 213. GiB for an array with shape (28610592445,) and data type float64

# %%
trainset = trainset.merge(book_title, how='left', on ='Book-Title')
testset = testset.merge(book_title, how='left', on ='Book-Title')

# %%
import gc
gc.collect()
# Out:
# 19

# %%
# Year-Of-Publication
# year = train_st['Year-Of-Publication']
# unique_year = sorted(year.unique())

# le = LabelEncoder()
# le=le.fit(unique_year)
# train_st['Year-Of-Publication']=le.transform(train_st['Year-Of-Publication'])

# for label in test_st['Year-Of-Publication'].unique():
#     if label not in le.classes_: 
#         le.classes_ = np.append(le.classes_, label)
# test_st['Year-Of-Publication']=le.transform(test_st['Year-Of-Publication'])

# %%
trainset.to_csv('trainset.csv', index=False)
testset.to_csv('testset.csv', index=False)

# %%
import pandas as pd
import numpy as np

testset = pd.read_csv('testset.csv')
trainset = pd.read_csv('trainset.csv')
sub = pd.read_csv('sample_submission.csv')

# %% [markdown]
# # 라벨인코딩

# %%
from sklearn.preprocessing import LabelEncoder
train_st = trainset.drop(['Location', 'Age'], axis=1).set_index('ID')
test_st = testset.drop(['Location', 'Age'], axis=1).set_index('ID')

qual_col = ['User-ID', 'Book-Author', 'Publisher', 'location1', 'location2', 'location3', 'Book-ID', 'Book-Title'
            ]
train_st[['User-ID', 'Book-Author', 'Publisher', 'location1', 'location2', 'location3', 'Book-ID', 'Book-Title'
            ]] = train_st[['User-ID', 'Book-Author', 'Publisher', 'location1', 'location2', 'location3', 'Book-ID', 'Book-Title'
            ]].astype(str)

test_st[['User-ID', 'Book-Author', 'Publisher', 'location1', 'location2', 'location3', 'Book-ID', 'Book-Title'
            ]] = test_st[['User-ID', 'Book-Author', 'Publisher', 'location1', 'location2', 'location3', 'Book-ID', 'Book-Title'
            ]].astype(str)



for i in qual_col:
  le = LabelEncoder()
  le=le.fit(train_st[i])
  elements = train_st[i].unique()
  train_st[i] = le.transform(train_st[i])
  test_st.loc[~(test_st[i].isin(elements)), i] = -1
  test_st.loc[test_st[i].isin(elements), i] = le.transform(test_st.loc[test_st[i].isin(elements), i])

# # 라벨링이 안된 원소들 라벨링
# for j in add_list[i]:
#     le = LabelEncoder()
#     le=le.fit(label_st[j])
#     train_st[j]=le.transform(train_st[j])
#     X_nan[j]=le.transform(X_nan[j])
#     if fill_list[i] != 'Delay':
#         test_nan[j]= testnan[j].apply(lambda x: le.transform([x])[0] if x in le.classes else -1)
#     else:
#         pass
#     le.classes = np.append(le.classes, -1)

# %%
test_st[test_st['Publisher'] == -1]
# Out:
#             User-ID Book-ID Book-Title Book-Author  Year-Of-Publication  \
# ID
# TEST_000090     136      -1         -1       26350               2000.0
# TEST_000290     252      -1         -1         926               1929.0
# TEST_000297     252      -1         -1       17196               2002.0
# TEST_000569     476      -1         -1          -1               1998.0
# TEST_000585     476      -1         -1          -1               1986.0
# ...             ...     ...        ...         ...                  ...
# TEST_060832      -1      -1         -1          -1               2000.0
# TEST_087196   45298      -1         -1          -1               2000.0
# TEST_104132      -1      -1         -1          -1               2001.0
# TEST_123100      -1      -1         -1          -1               1998.0
# TEST_150231   77866      -1         -1          -1               1998.0
#
#             Publisher location1  Age_fe location2 location3  ...       290  \
# ID                                                           ...
# TEST_000090        -1     11820     6.0       729         8  ...  0.006683
# TEST_000290        -1     10955     7.0      1207       194  ...  0.025274
# TEST_000297        -1     10955     7.0      1207       194  ...  0.044501
# TEST_000569        -1      3280     7.0       757        63  ...  0.029868
# TEST_000585        -1      3280     7.0       757        63  ...  0.028374
# ...               ...       ...     ...       ...       ...  ...       ...
# TEST_060832        -1        -1     5.0       706        81  ...  0.018713
# TEST_087196        -1      5997     6.0       706        85  ... -0.000382
# TEST_104132        -1        -1     9.0       176       194  ...  0.051134
# TEST_123100        -1        -1     7.0       706        63  ...  0.030691
# TEST_150231        -1       806     6.0       706       152  ...  0.023903
#
#                   291       292       293       294       295       296  \
# ID
# TEST_000090 -0.036331  0.018005 -0.015620 -0.023619 -0.026225  0.003122
# TEST_000290 -0.022030  0.008163 -0.011557 -0.005129  0.007812 -0.027920
# TEST_000297 -0.004590 -0.010638 -0.042634 -0.007301  0.014841  0.017725
# TEST_000569 -0.028834 -0.013324 -0.013189  0.013569 -0.016668  0.029976
# TEST_000585  0.007388  0.005677 -0.014146  0.013077 -0.027602  0.040060
# ...               ...       ...       ...       ...       ...       ...
# TEST_060832  0.000417 -0.056031 -0.007488  0.018508 -0.023435 -0.006350
# TEST_087196 -0.002509  0.049960  0.016011 -0.018116 -0.050311  0.015739
# TEST_104132 -0.008067  0.018556  0.005913  0.003698  0.001453 -0.009321
# TEST_123100  0.028360  0.078664 -0.027283 -0.019178 -0.076426  0.011151
# TEST_150231 -0.019291 -0.036828  0.000190  0.012092 -0.002222 -0.010943
#
#                   297       298       299
# ID
# TEST_000090  0.073433 -0.015277  0.004658
# TEST_000290  0.081768 -0.007084 -0.022884
# TEST_000297  0.034650  0.001205 -0.026205
# TEST_000569  0.069751  0.029945 -0.011685
# TEST_000585  0.065184  0.021913  0.000190
# ...               ...       ...       ...
# TEST_060832  0.060389  0.037017 -0.006756
# TEST_087196  0.080728 -0.006709  0.016952
# TEST_104132  0.034478 -0.006753  0.033874
# TEST_123100  0.072607 -0.017971 -0.011288
# TEST_150231  0.109757  0.006087 -0.028146
#
# [1314 rows x 310 columns]

# %%
train_st.to_csv('train_st.csv', index=False)
test_st.to_csv('test_st.csv', index=False)

# %%
train_st['Book-ID'].unique().shape
test_st['Book-ID'].unique().shape
# Out:
# (53908,)

# %% [markdown]
# # train

# %%
! pip install catboost
# Out:
# ㅜ
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting catboost
#   Downloading catboost-1.1.1-cp39-none-manylinux1_x86_64.whl (76.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 MB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/dist-packages (from catboost) (5.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.9/dist-packages (from catboost) (1.22.4)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.9/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.9/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.0->catboost) (2022.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (4.39.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly->catboost) (8.2.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->catboost) (3.15.0)
# Installing collected packages: catboost
# Successfully installed catboost-1.1.1

# %%
from sklearn.metrics import mean_squared_error
from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import KFold

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

train_st = pd.read_csv('train_st.csv')
test_st = pd.read_csv('test_st.csv')
sub = pd.read_csv('sample_submission.csv')
# train_st = train_st.set_index('ID') 

# 라벨인코딩 하지 않고 가능한지 테스트 -> 안됨 라벨인코딩 해야함 ->
# train_st = train_st.drop(['Location', 'Book-Title', 'Age', 'ID'], axis=1)
# test_st = test_st.drop(['Location', 'Book-Title', 'Age', 'ID'], axis=1)

# qual_col = ['User-ID', 'Book-Author', 'Publisher', 'location1', 'location2', 'location3',
#             ]
# train_st[['User-ID', 'Book-Author', 'Publisher', 'location1', 'location2', 'location3', 'Book-ID'
#             ]] = train_st[['User-ID', 'Book-Author', 'Publisher', 'location1', 'location2', 'location3', 'Book-ID'
#             ]].astype(str)

# test_st[['User-ID', 'Book-Author', 'Publisher', 'location1', 'location2', 'location3', 'Book-ID'
#             ]] = test_st[['User-ID', 'Book-Author', 'Publisher', 'location1', 'location2', 'location3', 'Book-ID'
#             ]].astype(str)
            
# for i in qual_col:
#   le = LabelEncoder()
#   le=le.fit(train_st[i])
#   train_st[i]=le.transform(train_st[i])
  
#   for label in test_st[i].unique():
#       if label not in le.classes_: 
#           le.classes_ = np.append(le.classes_, label)
#   test_st[i]=le.transform(test_st[i])

# %%
train_st['Age_fe'].value_counts()
# Out:
# 7.0     442096
# 8.0     130747
# 6.0      84935
# 9.0      77540
# 5.0      66635
# 10.0     18369
# 4.0      10033
# 11.0      9858
# 3.0       4332
# 13.0      2946
# 2.0       2461
# 12.0      1292
# 0.0       1262
# 1.0        351
# Name: Age_fe, dtype: int64

# %%
test_st
# Out:
#         User-ID      Book-ID  Book-Author  Year-Of-Publication  Publisher  \
# 0             8  BOOK_047966        35723             0.970543       1109
# 1             8  BOOK_119494        36407             0.972093       1230
# 2             8  BOOK_151775        90689             0.961240       7131
# 3             8  BOOK_176255         4114             0.965891      10565
# 4             8  BOOK_187307         8102             0.958140       1262
# ...         ...          ...          ...                  ...        ...
# 159616    83050  BOOK_186316        61537             0.961240       1262
# 159617    83050  BOOK_193314        51434             0.967442      12330
# 159618    83050  BOOK_255426        12012             0.972093       2326
# 159619    92099  BOOK_105206        14738             0.950388       7679
# 159620    92100  BOOK_244188        34955             0.967442      10420
#
#         location1  Age_fe  location2  location3         0  ...       290  \
# 0           12537     7.0        799        194 -0.000944  ... -0.034644
# 1           12537     7.0        799        194 -0.032446  ... -0.026114
# 2           12537     7.0        799        194  0.010236  ...  0.043567
# 3           12537     7.0        799        194 -0.059366  ...  0.008591
# 4           12537     7.0        799        194 -0.021614  ...  0.015150
# ...           ...     ...        ...        ...       ...  ...       ...
# 159616        510     7.0        706        194 -0.032737  ... -0.001869
# 159617        510     7.0        706        194  0.012411  ... -0.001147
# 159618        510     7.0        706        194 -0.019581  ...  0.016195
# 159619      14443     6.0       1328        170  0.020259  ...  0.001978
# 159620      14444     8.0        706        191  0.012903  ...  0.006531
#
#              291       292       293       294       295       296       297  \
# 0      -0.003111  0.037620  0.011788 -0.035681 -0.010836 -0.007659  0.063129
# 1       0.040331  0.070335 -0.066962 -0.050111 -0.002776  0.027553  0.092973
# 2       0.012572  0.037466 -0.009669  0.001944 -0.002511 -0.001907  0.053317
# 3      -0.019228  0.077177 -0.005567  0.004776  0.010840 -0.017549  0.071105
# 4      -0.000755  0.002423 -0.007509 -0.010293 -0.019241  0.016558  0.092083
# ...          ...       ...       ...       ...       ...       ...       ...
# 159616  0.058745  0.102661 -0.062944 -0.062983 -0.037703 -0.014672  0.094412
# 159617  0.077100  0.141744  0.018408  0.016757  0.039600 -0.025257  0.054022
# 159618 -0.015751  0.017569  0.001271  0.014004  0.007956 -0.004557  0.046310
# 159619  0.007557  0.083554 -0.027734 -0.013176 -0.029859 -0.028725  0.119853
# 159620  0.004721 -0.031059  0.021906 -0.023311  0.015180  0.010833  0.083503
#
#              298       299
# 0      -0.031226 -0.005416
# 1      -0.038342  0.042641
# 2      -0.018839 -0.002056
# 3       0.038395  0.057530
# 4      -0.007871  0.034509
# ...          ...       ...
# 159616 -0.034258 -0.013775
# 159617  0.009700 -0.096192
# 159618 -0.001917  0.013744
# 159619 -0.008980  0.035332
# 159620 -0.016959  0.010502
#
# [159621 rows x 309 columns]

# %%
x = train_st.drop(['Book-Rating'], axis=1)
y = train_st['Book-Rating']

# %% [markdown]
# ## NOFOLD

# %%
from sklearn.model_selection import train_test_split
from catboost import CatBoostRegressor, Pool

X_train, X_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=23, shuffle=True)
train_data = Pool(data=X_train, label=y_train, cat_features=qual_col)
valid_data = Pool(data=X_val, label=y_val, cat_features=qual_col)

model_cat = CatBoostRegressor(loss_function='RMSE', iterations = 3000)
model_cat.fit(train_data, eval_set=valid_data, use_best_model=True, early_stopping_rounds=50, verbose=10)
# Out:
# Learning rate set to 0.07282
# 0:	learn: 3.7920263	test: 3.7918060	best: 3.7918060 (0)	total: 921ms	remaining: 46m 2s
# 10:	learn: 3.5144794	test: 3.4903886	best: 3.4903886 (10)	total: 6s	remaining: 27m 9s

# %% [markdown]
# ## FOLD

# %%
fold = KFold(n_splits=5, shuffle=True, random_state=23)
x_test = test_st
folds=[]
models = []
for train_idx, valid_idx in fold.split(x, y):
        folds.append((train_idx, valid_idx))

cat_pred = np.zeros((x.shape[0], 1))
cat_pred_test = np.zeros((x_test.shape[0], 1))
for fold in range(5):
  print(f'\n----------------- Fold {fold} -----------------\n')
  train_idx, valid_idx = folds[fold]
  X_train, X_valid, y_train, y_valid = x.iloc[train_idx], x.iloc[valid_idx], y.iloc[train_idx], y.iloc[valid_idx]
  train_data = Pool(data=X_train, label=y_train, cat_features=qual_col)
  valid_data = Pool(data=X_valid, label=y_valid, cat_features=qual_col)

  model_cat = CatBoostRegressor(loss_function='RMSE', iterations =-1)
  model_cat.fit(train_data, eval_set=valid_data, use_best_model=True, early_stopping_rounds=50, verbose=10)
  models.append(model_cat)
  
  # cat_pred[valid_idx] = model_cat.predict(X_valid)
  cat_pred_test += model_cat.predict(x_test).reshape(-1, 1) / 5
# Out:
# ----------------- Fold 0 -----------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File _catboost.pyx:2286, in _catboost.get_float_feature()
#
# File _catboost.pyx:1139, in _catboost._FloatOrNan()
#
# File _catboost.pyx:951, in _catboost._FloatOrNanFromString()
#
# TypeError: Cannot convert 'b'BOOK_044368'' to float
#
# During handling of the above exception, another exception occurred:
#
# CatBoostError                             Traceback (most recent call last)
# Cell In[10], line 14
#      12 train_idx, valid_idx = folds[fold]
#      13 X_train, X_valid, y_train, y_valid = x.iloc[train_idx], x.iloc[valid_idx], y.iloc[train_idx], y.iloc[valid_idx]
# ---> 14 train_data = Pool(data=X_train, label=y_train, cat_features=qual_col)
#      15 valid_data = Pool(data=X_valid, label=y_valid, cat_features=qual_col)
#      17 model_cat = CatBoostRegressor(loss_function='RMSE', iterations =-1)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\catboost\core.py:792, in Pool.__init__(self, data, label, cat_features, text_features, embedding_features, embedding_features_data, column_description, pairs, delimiter, has_header, ignore_csv_quoting, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count, log_cout, log_cerr)
#     786         if isinstance(feature_names, PATH_TYPES):
#     787             raise CatBoostError(
#     788                 "feature_names must be None or have non-string type when the pool is created from "
#     789                 "python objects."
#     790             )
# --> 792         self._init(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
#     793                    group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#     794 super(Pool, self).__init__()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\catboost\core.py:1419, in Pool._init(self, data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#    1417 if feature_tags is not None:
#    1418     feature_tags = self._check_transform_tags(feature_tags, feature_names)
# -> 1419 self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
#    1420                 group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#
# File _catboost.pyx:3954, in _catboost._PoolBase._init_pool()
#
# File _catboost.pyx:4004, in _catboost._PoolBase._init_pool()
#
# File _catboost.pyx:3820, in _catboost._PoolBase._init_features_order_layout_pool()
#
# File _catboost.pyx:2786, in _catboost._set_features_order_data_pd_data_frame()
#
# File _catboost.pyx:2327, in _catboost.create_num_factor_data()
#
# File _catboost.pyx:2288, in _catboost.get_float_feature()
#
# CatBoostError: Bad value for num_feature[non_default_doc_idx=0,feature_idx=1]="BOOK_044368": Cannot convert 'b'BOOK_044368'' to float

# %%
cat_pred_test
# Out:
# array([[5.75626973],
#        [6.53292533],
#        [6.48623704],
#        ...,
#        [3.7475166 ],
#        [3.7439744 ],
#        [4.36308158]])

# %%
sub['Book-Rating'] = cat_pred_test

# %%
sub.to_csv('/content/drive/MyDrive/catboost_state_and_country_fold5.csv', index=False)

# %%
pred = model_cat.predict(x_test)

# %%
cat_pred_test += pred.reshape(-1, 1)

# %%
cat_pred_test
# Out:
# array([[5.14170611],
#        [6.02123094],
#        [5.97801314],
#        ...,
#        [3.84280955],
#        [3.61851887],
#        [4.65333165]])

# %%
  model_cat = CatBoostRegressor(loss_function='RMSE')
